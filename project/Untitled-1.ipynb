# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\user\Desktop\VNLData.csv")
df.head()
# Out:
#    MATCHID        TEAM1      TEAM2   SCORES                   SETSCORES  \
# 0    11700       France   Bulgaria  3\n:\n0         27-25\n25-21\n25-23
# 1    11701      Germany  Australia  3\n:\n0         25-19\n25-18\n25-16
# 2    11702        Japan       Iran  3\n:\n0         25-19\n25-22\n26-24
# 3    11703       Serbia   Slovenia  3\n:\n1  22-25\n25-18\n36-34\n25-18
# 4    11704  Netherlands     Russia  1\n:\n3  19-25\n22-25\n25-18\n20-25
#
#    ATTACKS1  ATTACKS2  BLOCKS1  BLOCKS2  SERVES1  ...  OPPONENT_ERRORS1  \
# 0        39        36        7        5        4  ...                27
# 1        42        28        5        3        5  ...                23
# 2        45        41        7        8        2  ...                22
# 3        66        53       14        9        3  ...                25
# 4        49        51        6       10        6  ...                25
#
#    OPPONENT_ERRORS2  TOTAL1  TOTAL2  DIGS1  DIGS2  RECEPTION1  RECEPTION2  \
# ...

# %%
df = df.drop(columns="MATCHID")
df.head()
# Out:
#          TEAM1      TEAM2   SCORES                   SETSCORES  ATTACKS1  \
# 0       France   Bulgaria  3\n:\n0         27-25\n25-21\n25-23        39
# 1      Germany  Australia  3\n:\n0         25-19\n25-18\n25-16        42
# 2        Japan       Iran  3\n:\n0         25-19\n25-22\n26-24        45
# 3       Serbia   Slovenia  3\n:\n1  22-25\n25-18\n36-34\n25-18        66
# 4  Netherlands     Russia  1\n:\n3  19-25\n22-25\n25-18\n20-25        49
#
#    ATTACKS2  BLOCKS1  BLOCKS2  SERVES1  SERVES2  OPPONENT_ERRORS1  \
# 0        36        7        5        4        4                27
# 1        28        5        3        5        0                23
# 2        41        7        8        2        1                22
# 3        53       14        9        3        4                25
# 4        51        6       10        6       10                25
#
#    OPPONENT_ERRORS2  TOTAL1  TOTAL2  DIGS1  DIGS2  RECEPTION1  RECEPTION2  \
# ...
